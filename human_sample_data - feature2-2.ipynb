# %%
import pandas as pd

# %%
df = pd.read_csv('human.csv', encoding='cp949')
df.head()
# Out:
#       아이디  나이              노동 계급  fnlwgt          학력  교육 수  \
# 0  H20001  39          State-gov   77516   Bachelors    13
# 1  H20002  50   Self-emp-not-inc   83311   Bachelors    13
# 2  H20003  38            Private  215646     HS-grad     9
# 3  H20004  53            Private  234721        11th     7
# 4  H20005  28            Private  338409   Bachelors    13
#
#                  혼인 상태                  직업              관계      인종       성별  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    자본 이득  자본 손실  주당 시간              모국
# 0   2174      0     40   United-States
# 1      0      0     13   United-States
# 2      0      0     40   United-States
# 3      0      0     40   United-States
# 4      0      0     40            Cuba

# %%
mdf = df.copy()

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   아이디     32561 non-null  object
#  1   나이      32561 non-null  int64
#  2   노동 계급   30725 non-null  object
#  3   fnlwgt  32561 non-null  int64
#  4   학력      32561 non-null  object
#  5   교육 수    32561 non-null  int64
#  6   혼인 상태   32561 non-null  object
#  7   직업      30718 non-null  object
#  8   관계      32561 non-null  object
#  9   인종      32561 non-null  object
#  10  성별      32561 non-null  object
#  11  자본 이득   32561 non-null  int64
#  12  자본 손실   32561 non-null  int64
#  13  주당 시간   32561 non-null  int64
#  14  모국      31978 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
## 파생변수 추가 (예측 전)

# %%
# 주당 시간2 파생변수 추가
mdf['교육 수'].value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: 교육 수, dtype: int64

# %%
mdf['교육 수'].describe()
# Out:
# count    32561.000000
# mean        10.080679
# std          2.572720
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: 교육 수, dtype: float64

# %%
mdf.loc[mdf['교육 수'] <= 8]
# Out:
#           아이디  나이         노동 계급  fnlwgt        학력  교육 수  \
# 3      H20004  53       Private  234721      11th     7
# 6      H20007  49       Private  160187       9th     5
# 15     H20016  34       Private  245487   7th-8th     4
# 18     H20019  38       Private   28887      11th     7
# 22     H20023  35   Federal-gov   76845       9th     5
# ...       ...  ..           ...     ...       ...   ...
# 32517  H52518  36       Private  131459   7th-8th     4
# 32522  H52523  58       Private  147707      11th     7
# 32526  H52527  32       Private  211349      10th     6
# 32535  H52536  22       Private  325033      12th     8
# 32551  H52552  32       Private   34066      10th     6
#
#                         혼인 상태                  직업              관계  \
# 3          Married-civ-spouse   Handlers-cleaners         Husband
# 6       Married-spouse-absent       Other-service   Not-in-family
# 15         Married-civ-spouse    Transport-moving         Husband
# 18         Married-civ-spouse               Sales         Husband
# 22         Married-civ-spouse     Farming-fishing         Husband
# ...                       ...                 ...             ...
# 32517      Married-civ-spouse        Craft-repair         Husband
# 32522      Married-civ-spouse               Sales         Husband
# 32526      Married-civ-spouse    Transport-moving         Husband
# 32535           Never-married     Protective-serv       Own-child
# 32551      Married-civ-spouse   Handlers-cleaners         Husband
#
#                         인종       성별  자본 이득  자본 손실  주당 시간              모국
# 3                    Black     Male      0      0     40   United-States
# 6                    Black   Female      0      0     16         Jamaica
# 15      Amer-Indian-Eskimo     Male      0      0     45          Mexico
# 18                   White     Male      0      0     50   United-States
# 22                   Black     Male      0      0     40   United-States
# ...                    ...      ...    ...    ...    ...             ...
# 32517                White     Male      0      0     40   United-States
# 32522                White     Male      0      0     40   United-States
# 32526                White     Male      0      0     40   United-States
# 32535                Black     Male      0      0     35   United-States
# 32551   Amer-Indian-Eskimo     Male      0      0     40   United-States
#
# [4253 rows x 15 columns]

# %%
# 주당 시간2 파생변수 생성 a,b
mdf.loc[mdf['교육 수']<=8,'교육 수2']='a'
mdf.loc[mdf['교육 수']>8,'교육 수2']='b'
mdf
# Out:
#           아이디  나이              노동 계급  fnlwgt           학력  교육 수  \
# 0      H20001  39          State-gov   77516    Bachelors    13
# 1      H20002  50   Self-emp-not-inc   83311    Bachelors    13
# 2      H20003  38            Private  215646      HS-grad     9
# 3      H20004  53            Private  234721         11th     7
# 4      H20005  28            Private  338409    Bachelors    13
# ...       ...  ..                ...     ...          ...   ...
# 32556  H52557  27            Private  257302   Assoc-acdm    12
# 32557  H52558  40            Private  154374      HS-grad     9
# 32558  H52559  58            Private  151910      HS-grad     9
# 32559  H52560  22            Private  201490      HS-grad     9
# 32560  H52561  52       Self-emp-inc  287927      HS-grad     9
#
#                      혼인 상태                  직업              관계      인종  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#             성별  자본 이득  자본 손실  주당 시간              모국 교육 수2
# 0         Male   2174      0     40   United-States     b
# 1         Male      0      0     13   United-States     b
# 2         Male      0      0     40   United-States     b
# 3         Male      0      0     40   United-States     a
# 4       Female      0      0     40            Cuba     b
# ...        ...    ...    ...    ...             ...   ...
# 32556   Female      0      0     38   United-States     b
# 32557     Male      0      0     40   United-States     b
# 32558   Female      0      0     40   United-States     b
# 32559     Male      0      0     20   United-States     b
# 32560   Female  15024      0     40   United-States     b
#
# [32561 rows x 16 columns]

# %%
# 혼인 상태2 파생변수 추가
mdf['주당 시간'].head()
# Out:
# 0    40
# 1    13
# 2    40
# 3    40
# 4    40
# Name: 주당 시간, dtype: int64

# %%
# 혼인 상태2 파생변수 생성 h1,h2
mdf['주당 시간'].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 92        1
# 74        1
# 94        1
# 82        1
# 87        1
# Name: 주당 시간, Length: 94, dtype: int64

# %%
mdf['주당 시간'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: 주당 시간, dtype: float64

# %%
mdf.loc[mdf['주당 시간'] <= 45]
# Out:
#           아이디  나이              노동 계급  fnlwgt           학력  교육 수  \
# 0      H20001  39          State-gov   77516    Bachelors    13
# 1      H20002  50   Self-emp-not-inc   83311    Bachelors    13
# 2      H20003  38            Private  215646      HS-grad     9
# 3      H20004  53            Private  234721         11th     7
# 4      H20005  28            Private  338409    Bachelors    13
# ...       ...  ..                ...     ...          ...   ...
# 32556  H52557  27            Private  257302   Assoc-acdm    12
# 32557  H52558  40            Private  154374      HS-grad     9
# 32558  H52559  58            Private  151910      HS-grad     9
# 32559  H52560  22            Private  201490      HS-grad     9
# 32560  H52561  52       Self-emp-inc  287927      HS-grad     9
#
#                      혼인 상태                  직업              관계      인종  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#             성별  자본 이득  자본 손실  주당 시간              모국 교육 수2
# 0         Male   2174      0     40   United-States     b
# 1         Male      0      0     13   United-States     b
# 2         Male      0      0     40   United-States     b
# 3         Male      0      0     40   United-States     a
# 4       Female      0      0     40            Cuba     b
# ...        ...    ...    ...    ...             ...   ...
# 32556   Female      0      0     38   United-States     b
# 32557     Male      0      0     40   United-States     b
# 32558   Female      0      0     40   United-States     b
# 32559     Male      0      0     20   United-States     b
# 32560   Female  15024      0     40   United-States     b
#
# [25422 rows x 16 columns]

# %%
# 주당 시간2 파생변수 생성 t1,t2
mdf.loc[mdf['주당 시간']<=45,'주당 시간2']='t1'
mdf.loc[mdf['주당 시간']>45,'주당 시간2']='t2'
mdf
# Out:
#           아이디  나이              노동 계급  fnlwgt           학력  교육 수  \
# 0      H20001  39          State-gov   77516    Bachelors    13
# 1      H20002  50   Self-emp-not-inc   83311    Bachelors    13
# 2      H20003  38            Private  215646      HS-grad     9
# 3      H20004  53            Private  234721         11th     7
# 4      H20005  28            Private  338409    Bachelors    13
# ...       ...  ..                ...     ...          ...   ...
# 32556  H52557  27            Private  257302   Assoc-acdm    12
# 32557  H52558  40            Private  154374      HS-grad     9
# 32558  H52559  58            Private  151910      HS-grad     9
# 32559  H52560  22            Private  201490      HS-grad     9
# 32560  H52561  52       Self-emp-inc  287927      HS-grad     9
#
#                      혼인 상태                  직업              관계      인종  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#             성별  자본 이득  자본 손실  주당 시간              모국 교육 수2 주당 시간2
# 0         Male   2174      0     40   United-States     b     t1
# 1         Male      0      0     13   United-States     b     t1
# 2         Male      0      0     40   United-States     b     t1
# 3         Male      0      0     40   United-States     a     t1
# 4       Female      0      0     40            Cuba     b     t1
# ...        ...    ...    ...    ...             ...   ...    ...
# 32556   Female      0      0     38   United-States     b     t1
# 32557     Male      0      0     40   United-States     b     t1
# 32558   Female      0      0     40   United-States     b     t1
# 32559     Male      0      0     20   United-States     b     t1
# 32560   Female  15024      0     40   United-States     b     t1
#
# [32561 rows x 17 columns]

# %%
# one-hot 인코딩
mdf_n2 = pd.get_dummies(mdf['교육 수2'])
mdf_n2.head()
# Out:
#    a  b
# 0  0  1
# 1  0  1
# 2  0  1
# 3  1  0
# 4  0  1

# %%
## 합치기
mdf = pd.concat([mdf, mdf_n2], axis=1)
mdf
# Out:
#           아이디  나이              노동 계급  fnlwgt           학력  교육 수  \
# 0      H20001  39          State-gov   77516    Bachelors    13
# 1      H20002  50   Self-emp-not-inc   83311    Bachelors    13
# 2      H20003  38            Private  215646      HS-grad     9
# 3      H20004  53            Private  234721         11th     7
# 4      H20005  28            Private  338409    Bachelors    13
# ...       ...  ..                ...     ...          ...   ...
# 32556  H52557  27            Private  257302   Assoc-acdm    12
# 32557  H52558  40            Private  154374      HS-grad     9
# 32558  H52559  58            Private  151910      HS-grad     9
# 32559  H52560  22            Private  201490      HS-grad     9
# 32560  H52561  52       Self-emp-inc  287927      HS-grad     9
#
#                      혼인 상태                  직업              관계      인종  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#             성별  자본 이득  자본 손실  주당 시간              모국 교육 수2 주당 시간2  a  b
# 0         Male   2174      0     40   United-States     b     t1  0  1
# 1         Male      0      0     13   United-States     b     t1  0  1
# 2         Male      0      0     40   United-States     b     t1  0  1
# 3         Male      0      0     40   United-States     a     t1  1  0
# 4       Female      0      0     40            Cuba     b     t1  0  1
# ...        ...    ...    ...    ...             ...   ...    ... .. ..
# 32556   Female      0      0     38   United-States     b     t1  0  1
# 32557     Male      0      0     40   United-States     b     t1  0  1
# 32558   Female      0      0     40   United-States     b     t1  0  1
# 32559     Male      0      0     20   United-States     b     t1  0  1
# 32560   Female  15024      0     40   United-States     b     t1  0  1
#
# [32561 rows x 19 columns]

# %%
# 결측치 처리
# mdf = mdf.dropna(subset=['노동 계급', '직업', '모국'])
# mdf.shape

# %%
obj = ['노동 계급', '학력', '혼인 상태', '직업', '관계', '인종', '성별', '모국','교육 수2','주당 시간2']
mdf[obj] = mdf[obj].apply(lambda x: x.astype('category').cat.codes)
mdf.head()
# Out:
#       아이디  나이  노동 계급  fnlwgt  학력  교육 수  혼인 상태  직업  관계  인종  성별  자본 이득  자본 손실  \
# 0  H20001  39      6   77516   9    13      4   0   1   4   1   2174      0
# 1  H20002  50      5   83311   9    13      2   3   0   4   1      0      0
# 2  H20003  38      3  215646  11     9      0   5   1   4   1      0      0
# 3  H20004  53      3  234721   1     7      2   5   0   2   1      0      0
# 4  H20005  28      3  338409   9    13      2   9   5   2   0      0      0
#
#    주당 시간  모국  교육 수2  주당 시간2  a  b
# 0     40  38      1       0  0  1
# 1     13  38      1       0  0  1
# 2     40  38      1       0  0  1
# 3     40  38      0       0  1  0
# 4     40   4      1       0  0  1

# %%
mdf.isnull().sum()
# Out:
# 아이디       0
# 나이        0
# 노동 계급     0
# fnlwgt    0
# 학력        0
# 교육 수      0
# 혼인 상태     0
# 직업        0
# 관계        0
# 인종        0
# 성별        0
# 자본 이득     0
# 자본 손실     0
# 주당 시간     0
# 모국        0
# 교육 수2     0
# 주당 시간2    0
# a         0
# b         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split  

X = mdf.drop(['아이디','성별'], axis=1) 
Y = mdf['성별']                    

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=11, random_state=0)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=11, random_state=0)

# %%
display(tree.score(X_test, y_test))
# Out:
# 0.8265569340375876

# %%
import xgboost as xgb
from xgboost import plot_importance
#import pan
import numpy as np

# %%
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

# %%
params = {'max_depth':3,
          'eta':0.1,
          'objective':'binary:logistic',
          'eval_metric':'logloss',
          'early_stoppings':100
         }
num_rounds = 400

# %%
# train 데이터 세트는 'train', evaluation(test) 데이터 세트는 'eval'로 명기
wlist = [(dtrain, 'train'),(dtest, 'eval')]
# 하이퍼 파라미터와 early stoppinig 파라미터를 train() 함수의 파라미터로 전달
xgb_model = xgb.train(params=params, dtrain=dtrain, num_boost_round=num
# [372]	train-logloss:0.26802	eval-logloss:0.29455
# [373]	train-logloss:0.26801	eval-logloss:0.29454
# [374]	train-logloss:0.26801	eval-logloss:0.29454
# [375]	train-logloss:0.26798	eval-logloss:0.29456
# [376]	train-logloss:0.26793	eval-logloss:0.29452
# [377]	train-logloss:0.26792	eval-logloss:0.29452
# [378]	train-logloss:0.26786	eval-logloss:0.29455
# [379]	train-logloss:0.26779	eval-logloss:0.29455
# [380]	train-logloss:0.26774	eval-logloss:0.29457
# [381]	train-logloss:0.26769	eval-logloss:0.29461
# [382]	train-logloss:0.26760	eval-logloss:0.29466
# [383]	train-logloss:0.26755	eval-logloss:0.29470
# [384]	train-logloss:0.26748	eval-logloss:0.29474
# [385]	train-logloss:0.26744	eval-logloss:0.29476
# [386]	train-logloss:0.26743	eval-logloss:0.29476
# [387]	train-logloss:0.26741	eval-logloss:0.29475
# [388]	train-logloss:0.26731	eval-logloss:0.29476
# [389]	train-logloss:0.26719	eval-logloss:0.29466
# [390]	train-logloss:0.26706	eval-logloss:0.29465
# [391]	train-logloss:0.26701	eval-logloss:0.29465
# [392]	train-logloss:0.26692	eval-logloss:0.29465
# [393]	train-logloss:0.26686	eval-logloss:0.29463
# [394]	train-logloss:0.26679	eval-logloss:0.29466
# [395]	train-logloss:0.26678	eval-logloss:0.29466
# [396]	train-logloss:0.26670	eval-logloss:0.29466
# [397]	train-logloss:0.26662	eval-logloss:0.29464
# [398]	train-logloss:0.26656	eval-logloss:0.29466
# [399]	train-logloss:0.26648	eval-logloss:0.29466

# %%
pred_probs = xgb_model.predict(dtest)
print('predict() 수행 결과값을 10개만 표시, 예측 확률값으로 표시됨')
print(np.round(pred_probs[:10], 3))

preds = [1 if x > 0.5 else 0 for x in pred_probs]
# Out:
# predict() 수행 결과값을 10개만 표시, 예측 확률값으로 표시됨
# [0.087 0.478 0.999 1.    0.986 0.548 0.597 0.286 0.1   0.315]

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix
def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    print('오차행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}'.format(accuracy, precision, recall))

# %%
get_clf_eval(y_test, preds)
# Out:
# 오차행렬
# [[2160  541]
#  [ 723 4717]]
# 정확도: 0.8447, 정밀도: 0.8971, 재현율: 0.8671

# %%
## 전개

# %%
new = pd.read_csv('human_new.csv', encoding='cp949')
new.head()
# Out:
#       아이디  나이       노동 계급  fnlwgt             학력  교육 수                혼인 상태  \
# 0  H00001  25     Private  226802           11th     7        Never-married
# 1  H00002  38     Private   89814        HS-grad     9   Married-civ-spouse
# 2  H00003  28   Local-gov  336951     Assoc-acdm    12   Married-civ-spouse
# 3  H00004  44     Private  160323   Some-college    10   Married-civ-spouse
# 4  H00005  18         NaN  103497   Some-college    10        Never-married
#
#                    직업          관계      인종  자본 이득  자본 손실  주당 시간              모국
# 0   Machine-op-inspct   Own-child   Black      0      0     40   United-States
# 1     Farming-fishing     Husband   White      0      0     50   United-States
# 2     Protective-serv     Husband   White      0      0     40   United-States
# 3   Machine-op-inspct     Husband   Black   7688      0     40   United-States
# 4                 NaN   Own-child   White      0      0     30   United-States

# %%
new.isnull().sum()
# Out:
# 아이디         0
# 나이          0
# 노동 계급     963
# fnlwgt      0
# 학력          0
# 교육 수        0
# 혼인 상태       0
# 직업        966
# 관계          0
# 인종          0
# 자본 이득       0
# 자본 손실       0
# 주당 시간       0
# 모국        274
# dtype: int64

# %%
X_train.head()
# Out:
#        나이  노동 계급  fnlwgt  학력  교육 수  혼인 상태  직업  관계  인종  자본 이득  자본 손실  주당 시간  \
# 26464  59      3   61885   2     8      0  13   2   2      0      0     35
# 16134  71      3  180733  12    14      4   7   1   4      0      0     20
# 4747   42      3  107762  12    14      2   9   0   4      0      0     40
# 8369   26      3   35917  11     9      2  11   0   4      0      0     40
# 5741   46      3  256522   3     2      4   6   3   4      0      0     40
#
#        모국  교육 수2  주당 시간2  a  b
# 26464  38      0       0  1  0
# 16134  38      1       0  0  1
# 4747   38      1       0  0  1
# 8369   38      1       0  0  1
# 5741   32      0       0  1  0

# %%
X_train.shape
# Out:
# (24420, 17)

# %%
new.shape
# Out:
# (16281, 14)

# %%
## 파생변수 추가(예측 후 / 전개)

# %%
new.loc[new['교육 수']<=8,'교육 수2']='a'
new.loc[new['교육 수']>8,'교육 수2']='b'

# %%
new.loc[new['주당 시간']<=45,'주당 시간2']='t1'
new.loc[new['주당 시간']>45,'주당 시간2']='t2'
new
# Out:
#           아이디  나이       노동 계급  fnlwgt             학력  교육 수  \
# 0      H00001  25     Private  226802           11th     7
# 1      H00002  38     Private   89814        HS-grad     9
# 2      H00003  28   Local-gov  336951     Assoc-acdm    12
# 3      H00004  44     Private  160323   Some-college    10
# 4      H00005  18         NaN  103497   Some-college    10
# ...       ...  ..         ...     ...            ...   ...
# 16276  H16277  20         NaN  216672   Some-college    10
# 16277  H16278  25     Private   61956      Bachelors    13
# 16278  H16279  33     Private  157216        Masters    14
# 16279  H16280  68         NaN  150250        Masters    14
# 16280  H16281  37     Private  112838        Masters    14
#
#                      혼인 상태                  직업              관계      인종  자본 이득  \
# 0            Never-married   Machine-op-inspct       Own-child   Black      0
# 1       Married-civ-spouse     Farming-fishing         Husband   White      0
# 2       Married-civ-spouse     Protective-serv         Husband   White      0
# 3       Married-civ-spouse   Machine-op-inspct         Husband   Black   7688
# 4            Never-married                 NaN       Own-child   White      0
# ...                    ...                 ...             ...     ...    ...
# 16276        Never-married                 NaN       Own-child   White      0
# 16277        Never-married     Exec-managerial       Own-child   White   4650
# 16278        Never-married               Sales   Not-in-family   White      0
# 16279   Married-civ-spouse                 NaN         Husband   White      0
# 16280   Married-civ-spouse     Exec-managerial         Husband   White      0
#
#        자본 손실  주당 시간              모국 교육 수2 주당 시간2
# 0          0     40   United-States     a     t1
# 1          0     50   United-States     b     t2
# 2          0     40   United-States     b     t1
# 3          0     40   United-States     b     t1
# 4          0     30   United-States     b     t1
# ...      ...    ...             ...   ...    ...
# 16276      0     30   United-States     b     t1
# 16277      0     45   United-States     b     t1
# 16278      0     40   United-States     b     t1
# 16279   1510     30   United-States     b     t1
# 16280      0     55   United-States     b     t2
#
# [16281 rows x 16 columns]

# %%
# one-hot 인코딩
new_n2 = pd.get_dummies(new['교육 수2'])
# 합치기
new = pd.concat([new, new_n2], axis=1)
new
# Out:
#           아이디  나이       노동 계급  fnlwgt             학력  교육 수  \
# 0      H00001  25     Private  226802           11th     7
# 1      H00002  38     Private   89814        HS-grad     9
# 2      H00003  28   Local-gov  336951     Assoc-acdm    12
# 3      H00004  44     Private  160323   Some-college    10
# 4      H00005  18         NaN  103497   Some-college    10
# ...       ...  ..         ...     ...            ...   ...
# 16276  H16277  20         NaN  216672   Some-college    10
# 16277  H16278  25     Private   61956      Bachelors    13
# 16278  H16279  33     Private  157216        Masters    14
# 16279  H16280  68         NaN  150250        Masters    14
# 16280  H16281  37     Private  112838        Masters    14
#
#                      혼인 상태                  직업              관계      인종  자본 이득  \
# 0            Never-married   Machine-op-inspct       Own-child   Black      0
# 1       Married-civ-spouse     Farming-fishing         Husband   White      0
# 2       Married-civ-spouse     Protective-serv         Husband   White      0
# 3       Married-civ-spouse   Machine-op-inspct         Husband   Black   7688
# 4            Never-married                 NaN       Own-child   White      0
# ...                    ...                 ...             ...     ...    ...
# 16276        Never-married                 NaN       Own-child   White      0
# 16277        Never-married     Exec-managerial       Own-child   White   4650
# 16278        Never-married               Sales   Not-in-family   White      0
# 16279   Married-civ-spouse                 NaN         Husband   White      0
# 16280   Married-civ-spouse     Exec-managerial         Husband   White      0
#
#        자본 손실  주당 시간              모국 교육 수2 주당 시간2  a  b
# 0          0     40   United-States     a     t1  1  0
# 1          0     50   United-States     b     t2  0  1
# 2          0     40   United-States     b     t1  0  1
# 3          0     40   United-States     b     t1  0  1
# 4          0     30   United-States     b     t1  0  1
# ...      ...    ...             ...   ...    ... .. ..
# 16276      0     30   United-States     b     t1  0  1
# 16277      0     45   United-States     b     t1  0  1
# 16278      0     40   United-States     b     t1  0  1
# 16279   1510     30   United-States     b     t1  0  1
# 16280      0     55   United-States     b     t2  0  1
#
# [16281 rows x 18 columns]

# %%
from sklearn.impute import SimpleImputer
imputer_con = SimpleImputer(strategy="most_frequent")  
con = ['노동 계급', '학력', '혼인 상태', '직업', '관계', '인종', '모국']
imputer_con.fit(new[con])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
x = imputer_con.transform(new[con])
x
# Out:
# array([[' Private', ' 11th', ' Never-married', ..., ' Own-child',
#         ' Black', ' United-States'],
#        [' Private', ' HS-grad', ' Married-civ-spouse', ..., ' Husband',
#         ' White', ' United-States'],
#        [' Local-gov', ' Assoc-acdm', ' Married-civ-spouse', ...,
#         ' Husband', ' White', ' United-States'],
#        ...,
#        [' Private', ' Masters', ' Never-married', ..., ' Not-in-family',
#         ' White', ' United-States'],
#        [' Private', ' Masters', ' Married-civ-spouse', ..., ' Husband',
#         ' White', ' United-States'],
#        [' Private', ' Masters', ' Married-civ-spouse', ..., ' Husband',
#         ' White', ' United-States']], dtype=object)

# %%
new[con] = x
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   아이디     16281 non-null  object
#  1   나이      16281 non-null  int64
#  2   노동 계급   16281 non-null  object
#  3   fnlwgt  16281 non-null  int64
#  4   학력      16281 non-null  object
#  5   교육 수    16281 non-null  int64
#  6   혼인 상태   16281 non-null  object
#  7   직업      16281 non-null  object
#  8   관계      16281 non-null  object
#  9   인종      16281 non-null  object
#  10  자본 이득   16281 non-null  int64
#  11  자본 손실   16281 non-null  int64
#  12  주당 시간   16281 non-null  int64
#  13  모국      16281 non-null  object
#  14  교육 수2   16281 non-null  object
#  15  주당 시간2  16281 non-null  object
#  16  a       16281 non-null  uint8
#  17  b       16281 non-null  uint8
# dtypes: int64(6), object(10), uint8(2)
# memory usage: 2.0+ MB

# %%
new.isnull().sum()
# Out:
# 아이디       0
# 나이        0
# 노동 계급     0
# fnlwgt    0
# 학력        0
# 교육 수      0
# 혼인 상태     0
# 직업        0
# 관계        0
# 인종        0
# 자본 이득     0
# 자본 손실     0
# 주당 시간     0
# 모국        0
# 교육 수2     0
# 주당 시간2    0
# a         0
# b         0
# dtype: int64

# %%
new.shape
# Out:
# (16281, 18)

# %%
X_train.shape
# Out:
# (24420, 17)

# %%
obj1 = ['노동 계급', '학력', '혼인 상태', '직업', '관계', '인종', '모국','교육 수2','주당 시간2']
new[obj1] = new[obj1].apply(lambda x: x.astype('category').cat.codes)
new.head()
# Out:
#       아이디  나이  노동 계급  fnlwgt  학력  교육 수  혼인 상태  직업  관계  인종  자본 이득  자본 손실  \
# 0  H00001  25      3  226802   1     7      4   6   3   2      0      0
# 1  H00002  38      3   89814  11     9      2   4   0   4      0      0
# 2  H00003  28      1  336951   7    12      2  10   0   4      0      0
# 3  H00004  44      3  160323  15    10      2   6   0   2   7688      0
# 4  H00005  18      3  103497  15    10      4   9   3   4      0      0
#
#    주당 시간  모국  교육 수2  주당 시간2  a  b
# 0     40  37      0       0  1  0
# 1     50  37      1       1  0  1
# 2     40  37      1       0  0  1
# 3     40  37      1       0  0  1
# 4     30  37      1       0  0  1

# %%
new.isnull().sum()
# Out:
# 아이디       0
# 나이        0
# 노동 계급     0
# fnlwgt    0
# 학력        0
# 교육 수      0
# 혼인 상태     0
# 직업        0
# 관계        0
# 인종        0
# 자본 이득     0
# 자본 손실     0
# 주당 시간     0
# 모국        0
# 교육 수2     0
# 주당 시간2    0
# a         0
# b         0
# dtype: int64

# %%
ndf = new.copy()
ndf.head()
# Out:
#       아이디  나이  노동 계급  fnlwgt  학력  교육 수  혼인 상태  직업  관계  인종  자본 이득  자본 손실  \
# 0  H00001  25      3  226802   1     7      4   6   3   2      0      0
# 1  H00002  38      3   89814  11     9      2   4   0   4      0      0
# 2  H00003  28      1  336951   7    12      2  10   0   4      0      0
# 3  H00004  44      3  160323  15    10      2   6   0   2   7688      0
# 4  H00005  18      3  103497  15    10      4   9   3   4      0      0
#
#    주당 시간  모국  교육 수2  주당 시간2  a  b
# 0     40  37      0       0  1  0
# 1     50  37      1       1  0  1
# 2     40  37      1       0  0  1
# 3     40  37      1       0  0  1
# 4     30  37      1       0  0  1

# %%
ndf['성별'] = tree.predict(ndf.loc[:,'나이':'b'])
ndf.head()
# Out:
#       아이디  나이  노동 계급  fnlwgt  학력  교육 수  혼인 상태  직업  관계  인종  자본 이득  자본 손실  \
# 0  H00001  25      3  226802   1     7      4   6   3   2      0      0
# 1  H00002  38      3   89814  11     9      2   4   0   4      0      0
# 2  H00003  28      1  336951   7    12      2  10   0   4      0      0
# 3  H00004  44      3  160323  15    10      2   6   0   2   7688      0
# 4  H00005  18      3  103497  15    10      4   9   3   4      0      0
#
#    주당 시간  모국  교육 수2  주당 시간2  a  b  성별
# 0     40  37      0       0  1  0   1
# 1     50  37      1       1  0  1   1
# 2     40  37      1       0  0  1   1
# 3     40  37      1       0  0  1   1
# 4     30  37      1       0  0  1   0

# %%
#df_tr.loc[df_tr['노동 계급'] == ' ?', '노동 계급'] = np.nan
#ndf.loc[ndf['성별']==1,'성별'] = 'Male'
#ndf.loc[ndf['성별']==0,'성별'] = 'Female'
#ndf.head()

# %%
dtest_ndf = xgb.DMatrix(data=ndf.loc[:,'나이':'b'])

# %%
ndf['성별'] = xgb_model.predict(dtest_ndf)

# %%
str = ['아이디','성별']
ndf[str].head()
# Out:
#       아이디        성별
# 0  H00001  0.736219
# 1  H00002  0.999954
# 2  H00003  0.999782
# 3  H00004  0.999905
# 4  H00005  0.311930

# %%
#ndf[str].to_csv('sampleSubmission_human.csv', encoding='cp949', index=False)

# %%
#movie_rename = movie.rename(index={0:'아바타'}, columns={'color':'색깔','director_name':'감독이름'})
ndf_rename = ndf.rename(columns={'아이디':'ID', '성별':'SEX'})
ndf_rename.head()
# Out:
#        ID  나이  노동 계급  fnlwgt  학력  교육 수  혼인 상태  직업  관계  인종  자본 이득  자본 손실  \
# 0  H00001  25      3  226802   1     7      4   6   3   2      0      0
# 1  H00002  38      3   89814  11     9      2   4   0   4      0      0
# 2  H00003  28      1  336951   7    12      2  10   0   4      0      0
# 3  H00004  44      3  160323  15    10      2   6   0   2   7688      0
# 4  H00005  18      3  103497  15    10      4   9   3   4      0      0
#
#    주당 시간  모국  교육 수2  주당 시간2  a  b       SEX
# 0     40  37      0       0  1  0  0.736219
# 1     50  37      1       1  0  1  0.999954
# 2     40  37      1       0  0  1  0.999782
# 3     40  37      1       0  0  1  0.999905
# 4     30  37      1       0  0  1  0.311930

# %%
str = ['ID','SEX']
ndf_rename[str].head()
# Out:
#        ID       SEX
# 0  H00001  0.736219
# 1  H00002  0.999954
# 2  H00003  0.999782
# 3  H00004  0.999905
# 4  H00005  0.311930

# %%
ndf_rename[str].to_csv('submission_human0.csv', encoding='cp949', index=False)

# %%
ndf_rename.shape
# Out:
# (16281, 19)
